# %%
import pandas as pd
label_path = '/Users/caobai/code/JaneChutingCao/lewagon_project/raw_data/train_labels.csv'
labels = pd.read_csv(label_path)

# %%
labels.damage_grade.value_counts()
# Out:
# 2    148259
# 3     87218
# 1     25124
# Name: damage_grade, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(labels.damage_grade)

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# 1    148259
# 2     87218
# 0     25124
# dtype: int64

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.10.0'

# %%
path = ('/Users/caobai/code/chantalwuer/earthquake_damage/processed_data/df_imputed.csv')
merged = pd.read_csv(path)

# %%
len(merged.columns.to_list())
# Out:
# 44

# %%
a = merged.columns.to_list()[0:11]
len(a)
# Out:
# 11

# %%
b = merged.columns.to_list()[11:22]
len(b)
# Out:
# 11

# %%
c = merged.columns.to_list()[22:33]
len(c)
# Out:
# 11

# %%
d = merged.columns.to_list()[33:44]
len(d)
# Out:
# 11

# %%
dist_id = merged.district_id.unique().tolist()
dist_name =['Okhaldhunga','Sindhuli','Ramechhap','Dolakha','Sindhupalchok','Kabhrepalanchok','Nuwakot','Rasuwa','Dhading','Makawanpur','Gorkha']

# %%
district_codes = { 
        12:'Okhaldhunga',
        20:'Sindhuli',
        21:'Ramechhap',
        22:'Dolakha',
        23:'Sindhupalchok',
        24:'Kabhrepalanchok'
        28:'Nuwakot',
        29:'Rasuwa',
        30:'Dhading',
        31:'Makawanpur',
        36:'Gorkha'
}
# Out:
#   Cell In [38], line 7
#     24:'Kabhrepalanchok'
#        ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
distict_dict = dict(zip(dist_name, dist_id))

# %%
distict_dict['Okhaldhunga']
# Out:
# 12

# %%
merged.has_superstructure_adobe_mud.value_counts()
# Out:
# 0    715382
# 1     31755
# Name: has_superstructure_adobe_mud, dtype: int64

# %%
municipality_codes = { 
        1201: 'Champadevi',
        1202: 'Chisankhugadhi',
        1203: 'Khijidemba',
        1204: 'Likhu',
        1205: 'Manebhanjyang',
        1206: 'Molung',
        1207: 'Siddhicharan',
        1208: 'Sunkoshi',
        2001: 'Dudhouli',
        2002: 'Ghyanglekha',
        2003: 'Golanjor',
        2004: 'Hariharpurgadhi',
        2005: 'Kamalamai',
        2006: 'Marin',
        2007: 'Phikkal',
        2008: 'Sunkoshi',
        2009: 'Tinpatan',
        2101: 'Doramba',
        2102: 'Gokulganga',
        2103: 'Khadadevi',
        2104: 'Likhu Tamakoshi',
        2105: 'Manthali',
        2106: 'Ramechhap',
        2107: 'Sunapati',
        2108: 'Umakunda',
        2201: 'baiteshwor',
        2202: 'Bhimeshwor',
        2203: 'Bigu',
        2204: 'Gaurishankar',
        2205: 'Jiri',
        2206: 'Kalinchok',
        2207: 'Melung',
        2208: 'Sailung',
        2209: 'Tamakoshi',
        2301: 'Barhabise',
        2302: 'Balefi',
        2303: 'Bhotekoshi',
        2304: 'Chautara sangachok gadhi',
        2305: 'Helambu',
        2306: 'Indrawati',
        2307: 'Jugal',
        2308: 'Langtang National Park',
        2309: 'lisangkhu pakhar',
        2310: 'Melamchi',
        2311: 'Panchpokhari Thangpal',
        2312: 'Sunkoshi',
        2313: 'Tripurasundari',
        2401: 'Banepa',
        2402: 'Bethanchowk',
        2403: 'Bhumlu',
        2404: 'Chaurideurali',
        2405: 'Dhulikhel',
        2406: 'Khanikhola',
        2407: 'Mahabharat',
        2408: 'Mandandeupur',
        2409: 'Namobuddha',
        2410: 'Panauti',
        2411: 'Panchkhal',
        2412: 'Roshi',
        2413: 'Temal',
        2801: 'Belkotgadhi',
        2802: 'Bidur',
        2803: 'Dupcheshwar',
        2804: 'Kakani',
        2805: 'Kispang',
        2807: 'Likhu',
        2808: 'Myagang',
        2809: 'Panchakanya',
        2810: 'Shivapuri',
        2811: 'Suryagadhi',
        2812: 'Tadi',
        2813: 'Tarakeshwor',
        2901: 'Aamachhodingmo',
        2902: 'Gosaikunda',
        2903: 'Kalika',
        2904: 'Naukunda',
        2905: 'Uttargaya',
        3001: 'Benighat Rorang',
        3002: 'Dhunibesi',
        3003: 'Gajuri',
        3004: 'Galchi',
        3005: 'Gangajamuna',
        3006: 'Jwalamukhi',
        3007: 'Khaniyabash',
        3008: 'Netrawati',
        3009: 'Nilakantha',
        3010: 'Rubi Valley',
        3011: 'Siddhalek',
        3012: 'Thakre',
        3013: 'Tripurasundari',
        3101: 'Bagmati',
        3102: 'Bakaiya',
        3103: 'Bhimphedi',
        3104: 'Hetauda',
        3105: 'Indrasarowar',
        3106: 'Kailash',
        3107: 'Makawanpurgadhi',
        3108: 'Manahari',
        3109: 'Parsa Wildlife Reserve',
        3110: 'Raksirang',
        3111: 'Thaha',
        3601: 'Aarughat',
        3602: 'Ajirkot',
        3603: 'Sulikot',
        3604: 'Bhimsen',
        3605: 'Chum nubri',
        3606: 'Dharche',
        3607: 'Gandaki',
        3608: 'Gorkha',
        3609: 'Palungtar',
        3610: 'Sahid lakhan',
        3611: 'Siranchok'
}

# %%
my_dict2 = {y: x for x, y in municipality_codes.items()}
my_dict2
# Out:
# {'Champadevi': 1201,
#  'Chisankhugadhi': 1202,
#  'Khijidemba': 1203,
#  'Likhu': 2807,
#  'Manebhanjyang': 1205,
#  'Molung': 1206,
#  'Siddhicharan': 1207,
#  'Sunkoshi': 2312,
#  'Dudhouli': 2001,
#  'Ghyanglekha': 2002,
#  'Golanjor': 2003,
#  'Hariharpurgadhi': 2004,
#  'Kamalamai': 2005,
#  'Marin': 2006,
#  'Phikkal': 2007,
#  'Tinpatan': 2009,
#  'Doramba': 2101,
#  'Gokulganga': 2102,
#  'Khadadevi': 2103,
#  'Likhu Tamakoshi': 2104,
#  'Manthali': 2105,
#  'Ramechhap': 2106,
#  'Sunapati': 2107,
#  'Umakunda': 2108,
#  'baiteshwor': 2201,
#  'Bhimeshwor': 2202,
#  'Bigu': 2203,
#  'Gaurishankar': 2204,
#  'Jiri': 2205,
#  'Kalinchok': 2206,
#  'Melung': 2207,
#  'Sailung': 2208,
#  'Tamakoshi': 2209,
#  'Barhabise': 2301,
#  'Balefi': 2302,
#  'Bhotekoshi': 2303,
#  'Chautara sangachok gadhi': 2304,
#  'Helambu': 2305,
#  'Indrawati': 2306,
#  'Jugal': 2307,
#  'Langtang National Park': 2308,
#  'lisangkhu pakhar': 2309,
#  'Melamchi': 2310,
# ...

# %%
muni_code = list(municipality_codes.keys())
muni_value = list(municipality_codes.values())
muni_dict = dict(zip(muni_value, muni_code))

# %%
int(str(muni_dict['Bigu'])[:2])
# Out:
# 22

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
merged.ward_id
# Out:
# 310405    2755
# 310404    2687
# 200506    2391
# 310412    2268
# 310411    2106
# 310419    1993
# 310415    1915
# 310409    1877
# 300903    1823
# 220704    1814
# 310408    1804
# 220205    1802
# 310413    1758
# 310418    1678
# 310402    1674
# 220209    1653
# 220701    1651
# 241004    1643
# 310401    1639
# 220202    1631
# 280213    1615
# 200505    1604
# 200504    1604
# 220207    1592
# 360806    1591
# 310417    1586
# 200111    1585
# 310403    1563
# 360304    1546
# 241111    1539
# 310806    1528
# 210501    1527
# 360907    1522
# 360808    1520
# 230405    1519
# 220808    1456
# 210704    1449
# 231011    1448
# 280209    1428
# 231009    1426
# 231012    1419
# 210101    1412
# 360902    1402
# 310414    1402
# 220106    1393
# 220201    1391
# 300902    1381
# 220208    1377
# 310416    1376
# 220803    1374
# 310807    1372
# 231107    1370
# 200507    1365
# 230401    1365
# 280203    1360
# 210407    1353
# 220903    1340
# 360904    1337
# ...

# %%
all_ward ={
    'Ward number 01':'01' ,
    'Ward number 02':'02' ,
    'Ward number 03':'03' ,
    'Ward number 04':'04' ,
    'Ward number 05':'05' ,
    'Ward number 06':'06' ,
    'Ward number 07':'07' ,
    'Ward number 08':'08',
    'Ward number 09':'09' ,
    'Ward number 10':'10',
    'Ward number 11':'11',
    'Ward number 12':'12',
    'Ward number 13':'13',
    'Ward number 14':'14',
    'Ward number 15':'15',
    'Ward number 16':'16',
    'Ward number 17':'17',
    'Ward number 18':'18',
    'Ward number 19':'19',
    'Ward number 20':'20',
}

# %%
merged.count_floors_pre_eq.value_counts()
# Out:
# 2    454207
# 3    175179
# 1    109437
# 4      6409
# 5      1519
# 6       285
# 7        75
# 9        15
# 8        11
# Name: count_floors_pre_eq, dtype: int64

# %%
merged.foundation_type.value_counts()
# Out:
# Mud mortar-Stone/Brick    619104
# Bamboo/Timber              54505
# Cement-Stone/Brick         37875
# RC                         31263
# Other                       4390
# Name: foundation_type, dtype: int64

# %%
int('09')
# Out:
# 9

# %%
import pickle
pickled_model = pickle.load(open('fit_best_model.pkl', 'rb'))

from earthquake_damage.data.model_input import get_model_input

# %%
output = get_model_input(district_id=23, municipality_id=2304, ward=4, age=34, floors=2, superstructure=1)

# %%
pre = pd.DataFrame(pickled_model.predict(output))
# Out:
# 1/1 [==============================] - 0s 15ms/step

# %%
sum([0.19233142, 0.24212366, 0.27943215, 0.14221132, 0.1439014 ])
# Out:
# 0.9999999500000001

# %%
pre.columns = ['Damage Grade 1', 'Damage Grade 2', 'Damage Grade 3', 'Damage Grade 4', 'Damage Grade 5']
pre.index = ['Probability']

# %%
pre = pre.T
pre
# Out:
#                 Probability
# Damage Grade 1     0.194050
# Damage Grade 2     0.230311
# Damage Grade 3     0.248475
# Damage Grade 4     0.156306
# Damage Grade 5     0.170858

# %%
pd.options.display.float_format = '{:.2%}'.format

# %%
pre
# Out:
#                 Probability
# Damage Grade 1       19.41%
# Damage Grade 2       23.03%
# Damage Grade 3       24.85%
# Damage Grade 4       15.63%
# Damage Grade 5       17.09%

# %%
prediction = pd.DataFrame(pickled_model.predict(output))
prediction.columns = ['Damage Grade 1', 'Damage Grade 2', 'Damage Grade 3', 'Damage Grade 4', 'Damage Grade 5']
prediction.index = ['Probability']
visual = prediction.copy()
visual
# Out:
# 1/1 [==============================] - 0s 19ms/step
#              Damage Grade 1  Damage Grade 2  Damage Grade 3  Damage Grade 4  \
# Probability          19.41%          23.03%          24.85%          15.63%
#
#              Damage Grade 5
# Probability          17.09%

# %%
import matplotlib.pyplot as plt
plt.plot(visual.T*100)
plt.tight_layout()

# %%
import seaborn as sns 
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
visual = pd.DataFrame(pickled_model.predict(output))
ax = sns.lineplot(data=visual.T*100, markers=True, dashes=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xlabel('Damage Grade')
ax.set_ylabel('Probability')
# Out:
# 1/1 [==============================] - 0s 13ms/step
# Text(0, 0.5, 'Probability')

# %%
foundation, floor, roof

# %%
merged.foundation_type.value_counts()
merged.foundation_type.unique()
# Out:
# array(['Other', 'Mud mortar-Stone/Brick', 'Cement-Stone/Brick',
#        'Bamboo/Timber', 'RC'], dtype=object)

# %%
merged.ground_floor_type.value_counts()
merged.ground_floor_type.unique()
# Out:
# array(['Mud', 'Brick/Stone', 'RC', 'Timber', 'Other'], dtype=object)

# %%
merged.roof_type.value_counts()
merged.roof_type.unique()
# Out:
# array(['Bamboo/Timber-Light roof', 'Bamboo/Timber-Heavy roof',
#        'RCC/RB/RBC'], dtype=object)

# %%
from earthquake_damage.data.model_input import get_model_input

# %%
get_model_input(district_id=12, municipality_id=1201, ward=5, age=5, 
                floors=2, superstructure=5, 
                foundation ='Mud mortar-Stone/Brick', 
                floor = 'Mud', roof = 'Bamboo/Timber-Light roof')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [167], line 1
# ----> 1 get_model_input(district_id=12, municipality_id=1201, ward=5, age=5,
#       2                 floors=2, superstructure=5,
#       3                 foundation ='Mud mortar-Stone/Brick',
#       4                 floor = 'Mud', roof = 'Bamboo/Timber-Light roof')
#
# TypeError: get_model_input() got an unexpected keyword argument 'foundation'

# %%
X_try = merged[['district_id','vdcmun_id','ward_id','count_floors_pre_eq','age_building','foundation_type','roof_type', 'ground_floor_type',
       'has_superstructure_adobe_mud',
       'has_superstructure_mud_mortar_stone', 
       'has_superstructure_stone_flag',
       'has_superstructure_cement_mortar_stone',
       'has_superstructure_mud_mortar_brick',
       'has_superstructure_cement_mortar_brick', 
       'has_superstructure_timber',
       'has_superstructure_bamboo', 
       'has_superstructure_rc_non_engineered',
       'has_superstructure_rc_engineered', 
       'has_superstructure_other']]

# %%
y_try = merged['damage_grade']
y_try = LabelEncoder().fit_transform(y_try)

# %%
pd.DataFrame(y_try).value_counts()
# Out:
# 4    276274
# 3    181467
# 2    132168
# 1     83609
# 0     73619
# dtype: int64

# %%
# Make Preprocessing Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, RobustScaler, LabelEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector

num_transformer = make_pipeline(RobustScaler())
num_col = make_column_selector(dtype_include=['int64', 'float64'])

cat_transformer = make_pipeline(OneHotEncoder(handle_unknown='ignore'))
cat_col = make_column_selector(dtype_include=['object'])

preprocessor = make_column_transformer((num_transformer, num_col),
                                        (cat_transformer, cat_col),
                                        remainder='passthrough')

prepro = preprocessor.fit(X_try) 
X_try = preprocessor.fit_transform(X_try)

# %%
X_try = pd.DataFrame(X_try)
X_try.columns =  preprocessor.get_feature_names_out()

# %%
X_try.head()
# Out:
#    pipeline-1__district_id  pipeline-1__vdcmun_id  pipeline-1__ward_id  \
# 0                 -150.00%               -149.13%             -149.14%
# 1                 -150.00%               -149.13%             -149.14%
# 2                 -150.00%               -149.13%             -149.14%
# 3                 -150.00%               -149.13%             -149.14%
# 4                 -150.00%               -149.13%             -149.14%
#
#    pipeline-1__count_floors_pre_eq  pipeline-1__age_building  \
# 0                         -100.00%                   -38.89%
# 1                         -100.00%                    -5.56%
# 2                         -100.00%                    22.22%
# 3                         -100.00%                    22.22%
# 4                         -100.00%                    77.78%
#
#    pipeline-1__has_superstructure_adobe_mud  \
# 0                                     0.00%
# 1                                     0.00%
# ...

# %%
from imblearn.over_sampling import SMOTE 
smote = SMOTE(random_state=42)
X_try, y_try = smote.fit_resample(X_try, y_try)

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_jobs=-1, n_estimators=100, random_state=42, colsample_bytree=0.5,
    gamma=0, learning_rate=1, max_depth=7, reg_lambda=10, subsample=0.8)

# %%
model.fit(X_try, y_try)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=7, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=-1,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto', ...)

# %%
import pickle 
pickle.dump(model, open('try_model.pkl', 'wb'))

# %%
def pro_x(user_input):  
    num_transformer = make_pipeline(RobustScaler())
    num_col = make_column_selector(dtype_include=['int64', 'float64'])

    cat_transformer = make_pipeline(OneHotEncoder(handle_unknown='ignore'))
    cat_col = make_column_selector(dtype_include=['object'])

    preprocessor = make_column_transformer((num_transformer, num_col),
                                            (cat_transformer, cat_col),
                                            remainder='passthrough')

    prepro = preprocessor.fit(X_try)
    return prepro
